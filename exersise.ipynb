# %%
import numpy as np

# %%
s = np.array([
    [5,3,4,6,7,8,9,1,2],
    [6,7,2,1,9,5,3,4,6],
    [1,9,8,3,4,2,5,6,7],

    [2,7,6,1,5,9,4,3,8],
    [9,5,1,4,3,8,2,7,6],
    [4,8,3,7,2,6,1,5,9],

    [8,1,2,7,5,3,6,4,9],
    [6,5,7,1,9,4,8,2,3],
    [4,9,3,6,8,2,7,1,5]
])

# Row check
for row in s:
    if np.sum(row) != 45:
        print("Sudoku is not valid (row issue)")
        break
else:
    print("Rows are valid")

# Column check (FIXED)
for col in s.T:   # or axis=0
    if np.sum(col) != 45:
        print("Sudoku is not valid (column issue)")
        break
else:
    print("Columns are valid")
# Out:
# Sudoku is not valid (row issue)
# Sudoku is not valid (column issue)

# %%
s.sum()
# Out:
# np.int64(403)

# %%
np.sum(s,axis=0)
# Out:
# array([45, 54, 36, 36, 52, 47, 45, 33, 55])

# %%
s[0:3,0:3]
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
s[0:3, 6:9]
# Out:
# array([[9, 1, 2],
#        [3, 4, 6],
#        [5, 6, 7]])

# %%
s[0:3, 3:6]
# Out:
# array([[6, 7, 8],
#        [1, 9, 5],
#        [3, 4, 2]])

# %%
for i in range(0,9,3):
    for j in range(0,9,3):
        n=s[i:i+3, j:j+3]
        print(n.sum())
# Out:
# 45
# 45
# 43
# 45
# 45
# 45
# 45
# 45
# 45

# %%
data = np.array([
    [18, 85, 78],
    [19, 92, 88],
    [17, 76, 70],
    [20, 90, 85],
    [18,65,85]
])

# %%
# Get the shape of the matrix
data.shape
# Out:
# (5, 3)

# %%
# find the average age of student.
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
#extract Math marks of all students.
data[:,1]
# Out:
# array([85, 92, 76, 90, 65])

# %%
#find the higest science mark.
np.max(data[0:,2])
# Out:
# np.int64(88)

# %%
# get details of the student who scored more than 90 in Math
data[data[:,1]> 90]
# Out:
# array([[19, 92, 88]])

# %%
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 70],
#        [20, 90, 85],
#        [18, 65, 85]])

# %%
# increase Math marks of all students by 5
data[0:,1]+=5
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 70],
#        [20, 95, 85],
#        [18, 70, 85]])

# %%
# find how many studets are younger than 19
len(data [data[:,0]<19])
# Out:
# 3

# %%
# claculate the average marks in each subject (colume-wise mean)
np.mean(data[:,1:], axis=0)
# Out:
# array([86.6, 81.2])

# %%
# get data of student who scored at least 80 in both subject
data[(data[:,1]>= 80) & (data[:,2] >= 80)]
# Out:
# array([[19, 97, 88],
#        [20, 95, 85]])

# %%
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 70],
#        [20, 95, 85],
#        [18, 70, 85]])

# %%
# replace all science marks < 75 with 0
data[:,2][data[:,2]<75]=0
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81,  0],
#        [20, 95, 85],
#        [18, 70, 85]])
