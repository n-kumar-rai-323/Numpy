# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])

# %%
# Print array
print("Array:",a)
# Out:
# Array: [1 2 3 4 5]

# %%
#Print type
print("Type:",type(a))
# Out:
# Type: <class 'numpy.ndarray'>

# %%
# Print shape
print("Shape:",a.shape)
# Out:
# Shape: (5,)

# %%
# print number of dimensions
print("ndim", a.ndim)
# Out:
# ndim 1
