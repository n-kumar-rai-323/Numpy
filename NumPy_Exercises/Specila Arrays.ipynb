# %%
import numpy as np

# %%
a =np.zeros((3,3))
print("Shape: ",a.shape)
print(a)
# Out:
# Shape:  (3, 3)
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
a =np.ones((2,4))
print("Shape: ", a.shape)
# Out:
# Shape:  (2, 4)

# %%
a =np.eye(4)
print("Shape: ",a.shape)
# Out:
# Shape:  (4, 4)

# %%
a = np.arange(1,11)
print("Shape: ", a.shape)
# Out:
# Shape:  (10,)
