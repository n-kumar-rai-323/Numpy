# %%
import numpy as np

# %%
a = np.array([10,20,30,40,50])
print("First element",a[0])
print("last element ",a[-1])
print("Middle element: ",a[2])
print("Element from index1 to 3", a[0:3])
# Out:
# First element 10
# last element  50
# Middle element:  30
# Element from index1 to 3 [10 20 30]
